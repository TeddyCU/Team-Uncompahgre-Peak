# %% [markdown]
# ### Load Packages

# %%
import pandas as pd
import numpy as np
import urllib.request, json 
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
q1= pd.read_csv('waqi-covid19-airqualitydata-2019Q1.csv',skiprows=[0,1,2,3])
q1.head()

data20= pd.read_csv('waqi-covid19-airqualitydata-2020.csv',skiprows=[0,1,2,3])
data20.head()
# Out:
#          Date Country       City Specie  count   min   max  median  variance
# 0  2020-03-08      AE  Abu Dhabi    dew    186  -1.0  19.0    15.0    359.63
# 1  2020-03-09      AE  Abu Dhabi    dew    192   9.0  19.0    15.0     40.73
# 2  2020-03-22      AE  Abu Dhabi    dew    190  16.0  21.5    19.0     11.82
# 3  2020-04-07      AE  Abu Dhabi    dew    158   7.0  19.0    15.0     53.93
# 4  2020-04-11      AE  Abu Dhabi    dew    192   2.0  19.0     6.0    181.78

# %% [markdown]
# ### data exploratory

# %%
data20.Country.unique()
# Out:
# array(['AE', 'AT', 'EE', 'FR', 'KG', 'SK', 'CL', 'DE', 'PH', 'UA', 'UZ',
#        'IE', 'IL', 'PK', 'PL', 'CO', 'ML', 'BO', 'FI', 'GT', 'SG', 'SV',
#        'TW', 'BG', 'CH', 'IQ', 'KW', 'MK', 'NZ', 'SE', 'NP', 'RE', 'UG',
#        'LT', 'BA', 'BR', 'CA', 'CY', 'HK', 'IS', 'LA', 'MN', 'KR', 'AR',
#        'BD', 'CI', 'CR', 'CZ', 'EC', 'ES', 'MX', 'GB', 'GH', 'IR', 'IT',
#        'PT', 'TJ', 'TR', 'AF', 'ET', 'GR', 'ID', 'JO', 'LK', 'TM', 'AU',
#        'BH', 'CN', 'RU', 'NL', 'ZA', 'XK', 'GN', 'JP', 'KZ', 'MY', 'PE',
#        'RO', 'SA', 'US', 'BE', 'CW', 'DK', 'DZ', 'MO', 'NO', 'RS', 'VN',
#        'GE', 'HR', 'HU', 'IN', 'MM', 'PR', 'TH'], dtype=object)

# %%
china= data20[data20['Country']=='CN']
china.City.unique()
# Out:
# array(['Beijing', 'Jieyang', 'Kunming', 'Hangzhou', 'Chongqing',
#        'Qingdao', 'Haikou', 'Ürümqi', 'Qiqihar', 'Guiyang', 'Shenzhen',
#        'Yunfu', 'Xuchang', 'Yinchuan', 'Shenyang', 'Lhasa', 'Shanghai',
#        'Changchun', 'Foshan', 'Nanning', 'Fushun', 'Hefei', 'Chengdu',
#        'Hohhot', 'Qinhuangdao', 'Shijiazhuang', 'Shantou', 'Zhengzhou',
#        'Nanjing', 'Xining', 'Xi’an', 'Zhuzhou', 'Wuhan', 'Tianjin',
#        'Changzhou', 'Nanchang', 'Shiyan', 'Xinxiang', 'Suzhou', 'Harbin',
#        'Lanzhou', 'Jinan', 'Changsha', 'Hegang', 'Anyang', 'Wuxi',
#        'Taiyuan', 'Guangzhou', 'Fuzhou', 'Ningbo', 'Xiamen', 'Dongguan'],
#       dtype=object)

# %% [markdown]
# ### Start to create graph

# %%
#extract main cities in china
main=['Beijing','Shanghai','Hangzhou','Nanjing','Shenzhen','Chengdu']

# %%
main_city = china[china['City'].isin(main)]

# %%
#group by city and median
main_city = round(main_city.groupby(['City'])[['median']].mean().reset_index(),2)
main_city.head()
# Out:
#        City  median
# 0   Beijing   93.61
# 1   Chengdu  110.39
# 2  Hangzhou  107.51
# 3   Nanjing  108.09
# 4  Shanghai  100.03

# %%
#start to create bubble plot for 2020 Q1 air quality in china main cities

large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")

# %matplotlib inline

categories = np.unique(main_city['City'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

fig = plt.figure(figsize=(14,8), dpi=120, facecolor='w', edgecolor='k')    
for i, category in enumerate(categories):
    data_ = main_city.loc[main_city.City==category, :]
    data_.index = range(data_.shape[0])
    plt.scatter('City', 'median', data=data_
                , s= main_city.loc[main_city.City==category, "median"]*15
                , c=np.array(colors[i]).reshape(1,-1)
                , label=str(category)
                , edgecolors= colors[i]
                , alpha = 0.7
                , linewidths=.5
               )

    for i in range(main_city.loc[main_city.City==category, :].shape[0]):
        plt.text(data_.loc[i,"City"]
                 ,data_.loc[i,"median"]
                 ,s=data_.loc[i,"median"] 
                 ,fontdict={"fontsize":12} 
                )

plt.gca().set(ylim=(80, 200),
              xlabel='city', ylabel='median')
plt.xticks(np.unique(main_city['City']),fontsize=12,rotation=45,horizontalalignment='right')
plt.yticks(fontsize=12)
plt.title("2020 Q1 Air Quality in China", fontsize=20)
plt.legend(fontsize=12
           ,markerscale=0.5
          )
plt.show()

# %% [markdown]
# ### Start to create graph for 2019 Q1 air quaity in China main cities

# %%
china_Q1= q1[q1['Country']=='CN']
china_Q1.head()
# Out:
#               Date Country     City       Specie  count   min   max  median  \
# 384292  2019-03-22      CN  Beijing  temperature    456   0.0  14.5     9.5
# 384293  2019-03-27      CN  Beijing  temperature    480   2.5  22.0    10.5
# 384294  2018-12-31      CN  Beijing  temperature    480 -14.0  -3.0    -9.5
# 384295  2019-01-22      CN  Beijing  temperature    480  -1.0  11.1     3.0
# 384296  2019-02-04      CN  Beijing  temperature    480  -7.5   3.0    -4.0
#
#         variance
# 384292    238.98
# 384293    415.96
# 384294    151.43
# 384295    194.82
# 384296    121.93

# %%
main2=['Beijing','Shanghai','Hangzhou','Nanjing','Shenzhen','Chengdu']

# %%
main_city_q1 = china_Q1[china_Q1['City'].isin(main2)]
main_city_q1.City.unique()
# Out:
# array(['Beijing', 'Hangzhou', 'Shenzhen', 'Shanghai', 'Chengdu',
#        'Nanjing'], dtype=object)

# %%
main_city2 = round(main_city_q1.groupby(['City'])[['median']].mean().reset_index(),2)
main_city2.head()
# Out:
#        City  median
# 0   Beijing  111.71
# 1   Chengdu  121.59
# 2  Hangzhou  148.96
# 3   Nanjing  123.86
# 4  Shanghai  111.30

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")

# %matplotlib inline

categories = np.unique(main_city2['City'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

fig = plt.figure(figsize=(14,8), dpi=120, facecolor='w', edgecolor='k')    
for i, category in enumerate(categories):
    data_ = main_city2.loc[main_city2.City==category, :]
    data_.index = range(data_.shape[0])
    plt.scatter('City', 'median', data=data_
                , s= main_city2.loc[main_city2.City==category, "median"]*15
                , c=np.array(colors[i]).reshape(1,-1)
                , label=str(category)
                , edgecolors= colors[i]
                , alpha = 0.7
                , linewidths=.5
               )


    for i in range(main_city2.loc[main_city2.City==category, :].shape[0]):
        plt.text(data_.loc[i,"City"]
                 ,data_.loc[i,"median"]
                 ,s=data_.loc[i,"median"] 
                 ,fontdict={"fontsize":12} 
                 ,horizontalalignment='center' 
                )

plt.gca().set(ylim=(80, 200),
              xlabel='city', ylabel='median')
plt.xticks(np.unique(main_city2['City']),fontsize=12,rotation=45,horizontalalignment='right')
plt.yticks(fontsize=12)
plt.title("2019 Q1 Air Quality in China", fontsize=22)
plt.legend(fontsize=12
           ,markerscale=0.5
          )
plt.show()

# %% [markdown]
# ### US 2020

# %%
us20= data20[data20['Country']=='US']
us20.City.unique()
# Out:
# array(['Oklahoma City', 'Raleigh', 'Memphis', 'Jackson', 'Boston',
#        'Richmond', 'Portland', 'Boise', 'Austin', 'Honolulu', 'Fresno',
#        'Milwaukee', 'Columbia', 'Hartford', 'Washington D.C.', 'Chicago',
#        'Houston', 'Indianapolis', 'Atlanta', 'Charlotte', 'Sacramento',
#        'Oakland', 'Providence', 'Staten Island', 'Brooklyn',
#        'Springfield', 'The Bronx', 'San Jose', 'Los Angeles', 'Detroit',
#        'Little Rock', 'Baltimore', 'Phoenix', 'Omaha', 'El Paso',
#        'Dallas', 'Seattle', 'Manhattan', 'Miami', 'Jacksonville',
#        'Las Vegas', 'San Antonio', 'Philadelphia', 'San Diego',
#        'Columbus', 'Saint Paul', 'Denver', 'Salt Lake City',
#        'Albuquerque', 'San Francisco', 'Salem', 'Madison', 'Nashville',
#        'Tucson', 'Queens', 'Tallahassee', 'Fort Worth'], dtype=object)

# %%
#Extract six major cities in US in 2020 
mainus=['Washington D.C.','Los Angeles','San Francisco','Manhattan','Chicago','Seattle']
main_us20= us20[us20['City'].isin(mainus)]
main_us20.City.unique()
main_us20.head()
# Out:
#               Date Country             City       Specie  count  min   max  \
# 512328  2020-01-20      US  Washington D.C.  temperature    120 -6.1   2.0
# 512329  2020-02-25      US  Washington D.C.  temperature     80  7.5  12.7
# 512330  2020-03-08      US  Washington D.C.  temperature    120 -3.1  17.9
# 512331  2020-03-19      US  Washington D.C.  temperature    119  7.9  24.6
# 512332  2020-04-14      US  Washington D.C.  temperature    112  3.7  15.4
#
#         median  variance
# 512328    -3.2     49.84
# 512329    10.0     11.61
# 512330     9.5    316.98
# 512331    13.1    197.76
# 512332    10.4     86.65

# %%
main_uscity20 = round(main_us20.groupby(['City'])[['median']].mean().reset_index(),2)
main_uscity20.head()
# Out:
#             City  median
# 0        Chicago   97.89
# 1    Los Angeles  100.90
# 2      Manhattan  107.49
# 3  San Francisco  108.03
# 4        Seattle  100.87

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")

# %matplotlib inline

categories = np.unique(main_uscity20['City'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

fig = plt.figure(figsize=(14,8), dpi=120, facecolor='w', edgecolor='k')    
for i, category in enumerate(categories):
    data_ = main_uscity20.loc[main_uscity20.City==category, :]
    data_.index = range(data_.shape[0])
    plt.scatter('City', 'median', data=data_
                , s= main_uscity20.loc[main_uscity20.City==category, "median"]*15
                , c=np.array(colors[i]).reshape(1,-1)
                , label=str(category)
                , edgecolors= colors[i]
                , alpha = 0.7
                , linewidths=.5
               )


    for i in range(main_uscity20.loc[main_uscity20.City==category, :].shape[0]):
        plt.text(data_.loc[i,"City"]
                 ,data_.loc[i,"median"]
                 ,s=data_.loc[i,"median"] 
                 ,fontdict={"fontsize":12} 
                 ,horizontalalignment='center' 
                )

plt.gca().set(ylim=(80, 200),
              xlabel='city', ylabel='median')
plt.xticks(np.unique(main_uscity20['City']),fontsize=12,rotation=45,horizontalalignment='right')
plt.yticks(fontsize=12)
plt.title("2020 Q1 Air Quality in US", fontsize=22)
plt.legend(fontsize=12
           ,markerscale=0.5
          )
plt.show()

# %% [markdown]
# ### US 2019

# %%
us19= q1[q1['Country']=='US']
us19.City.unique()
# Out:
# array(['Oklahoma City', 'Raleigh', 'Memphis', 'Jackson', 'Boston',
#        'Richmond', 'Portland', 'Boise', 'Austin', 'Honolulu', 'Fresno',
#        'Milwaukee', 'Columbia', 'Hartford', 'Washington D.C.', 'Chicago',
#        'Houston', 'Indianapolis', 'Atlanta', 'Charlotte', 'Sacramento',
#        'Oakland', 'Providence', 'Staten Island', 'Brooklyn',
#        'Springfield', 'The Bronx', 'San Jose', 'Los Angeles', 'Detroit',
#        'Little Rock', 'Baltimore', 'Phoenix', 'Omaha', 'El Paso',
#        'Dallas', 'Seattle', 'Manhattan', 'Miami', 'Jacksonville',
#        'Las Vegas', 'San Antonio', 'Philadelphia', 'San Diego',
#        'Columbus', 'Saint Paul', 'Denver', 'Salt Lake City',
#        'Albuquerque', 'San Francisco', 'Salem', 'Madison', 'Nashville',
#        'Tucson', 'Queens', 'Tallahassee', 'Fort Worth'], dtype=object)

# %%
#Extract six major cities in US in 2019
mainus2=['Washington D.C.','Los Angeles','San Francisco','Manhattan','Chicago','Seattle']
main_us19= us19[us19['City'].isin(mainus2)]
main_us19.City.unique()
main_us19.head()
# Out:
#               Date Country             City      Specie  count  min  max  \
# 103697  2019-03-04      US  Washington D.C.  wind-speed    104  0.1  8.4
# 103698  2019-01-06      US  Washington D.C.  wind-speed    115  0.1  6.7
# 103699  2019-01-08      US  Washington D.C.  wind-speed    103  0.1  7.7
# 103700  2019-01-19      US  Washington D.C.  wind-speed     91  0.1  5.5
# 103701  2019-01-26      US  Washington D.C.  wind-speed     52  0.2  3.5
#
#         median  variance
# 103697     3.6     52.10
# 103698     1.5     28.08
# 103699     2.0     28.63
# 103700     1.3     16.36
# 103701     1.0      8.41

# %%
main_uscity19 = round(main_us19.groupby(['City'])[['median']].mean().reset_index(),2)
main_uscity19.head()
# Out:
#             City  median
# 0        Chicago  111.35
# 1    Los Angeles  102.00
# 2      Manhattan  110.30
# 3  San Francisco  118.94
# 4        Seattle  108.27

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")

# %matplotlib inline

categories = np.unique(main_uscity19['City'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

fig = plt.figure(figsize=(14,8), dpi=120, facecolor='w', edgecolor='k')    
for i, category in enumerate(categories):
    data_ = main_uscity19.loc[main_uscity19.City==category, :]
    data_.index = range(data_.shape[0])
    plt.scatter('City', 'median', data=data_
                , s= main_uscity19.loc[main_uscity19.City==category, "median"]*15
                , c=np.array(colors[i]).reshape(1,-1)
                , label=str(category)
                , edgecolors= colors[i]
                , alpha = 0.7
                , linewidths=.5
               )


    for i in range(main_uscity19.loc[main_uscity19.City==category, :].shape[0]):
        plt.text(data_.loc[i,"City"]
                 ,data_.loc[i,"median"]
                 ,s=data_.loc[i,"median"] 
                 ,fontdict={"fontsize":12} 
                 ,horizontalalignment='center' 
                )

plt.gca().set(ylim=(80, 200),
              xlabel='city', ylabel='median')
plt.xticks(np.unique(main_uscity19['City']),fontsize=12,rotation=45,horizontalalignment='right')
plt.yticks(fontsize=12)
plt.title("2019 Q1 Air Quality in US", fontsize=22)
plt.legend(fontsize=12
           ,markerscale=0.5
          )
plt.show()
